# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
from params import *
import cv2
# import torchvideo as tv

# %%
cam = cv2.VideoCapture('dataset/video_test.avi')

# videodataset = tv.datasets.VideoDataset('./dataset/video_test.mp4')
# print(len(videodataset))

ret , frame = cam.read()
plt.imshow(frame)

print(np.empty((2,4,5)))
# Out:
# [[[ 4.68937394e-310  0.00000000e+000 -2.15446264e-131  2.96439388e-323
#     4.68918630e-310]
#   [ 0.00000000e+000  5.43472210e-323 -2.15446264e-131  5.92878775e-323
#     4.68918630e-310]
#   [ 0.00000000e+000  6.91691904e-323 -2.15446264e-131  7.41098469e-323
#     4.68918630e-310]
#   [ 0.00000000e+000  1.13635099e-322 -2.15446264e-131  1.18575755e-322
#     4.68918630e-310]]
#
#  [[ 0.00000000e+000  9.88131292e-324 -2.15446264e-131  1.48219694e-323
#     4.68918630e-310]
#   [ 0.00000000e+000  8.39911598e-323 -2.15446264e-131  8.89318163e-323
#     4.68918630e-310]
#   [ 0.00000000e+000  9.88131292e-323 -2.15446264e-131  1.03753786e-322
#     4.68918630e-310]
#   [ 0.00000000e+000  3.95252517e-323 -2.15446264e-131  4.44659081e-323
#     4.68918630e-310]]]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=29eff7bb-7336-4128-aac7-73781d5f9521' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
